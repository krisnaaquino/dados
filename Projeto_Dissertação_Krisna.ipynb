# %% [markdown]
# <a href="https://colab.research.google.com/github/krisnaaquino/dados/blob/main/Projeto_Disserta%C3%A7%C3%A3o_Krisna.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **MINING HEALTH –   MINERAÇÃO DE DADOS PARA PREDIÇÃO E DIAGNÓSTICO PRECOCE DE DOENÇAS **
#
#
#
# **Sistema de Informação sobre Mortalidade – SIM**
#
# O Sistema de Informação sobre Mortalidade (SIM), desenvolvido pelo Ministério da Saúde em 1975, é produto da unificação de mais de quarenta modelos de Declaração de Óbito utilizados ao longo dos anos, para coletar dados sobre mortalidade no país. Com sua longa série temporal, o SIM é um patrimônio nacional, visto que possui informações fundamentais para que possamos conhecer os aspectos referentes à mortalidade no Brasil e às causas de adoecimento que levaram ao óbito. É, ainda, **um dos principais instrumentos para apoiar a elaboração de políticas públicas de saúde e seguridade social mais efetivas visando à prevenção, promoção e cuidado em saúde.**
#
#
# Base de Dados: Base de Registros de 2020 à 2022
#
#
#
# Dicionário de dados:
# https://diaad.s3.sa-east-1.amazonaws.com/sim/Mortalidade_Geral+-+Estrutura.pdf

# %% [markdown]
# # 1) Importação de dados

# %%
#Importar arquivo csv SIM 2020
#head() irá mostrar por padrão as 5 primeiras linhas do que existe dentro de um conjunto de dados dentro de um objeto do pandas
import pandas as pd
dados2020 = pd.read_csv("https://diaad.s3.sa-east-1.amazonaws.com/sim/Mortalidade_Geral_2020.csv",  sep=";")
dados2020.head()
# Out:
# <ipython-input-2-bad2290493a9>:4: DtypeWarning: Columns (66,79) have mixed types. Specify dtype option on import or set low_memory=False.
#   dados2020 = pd.read_csv("https://diaad.s3.sa-east-1.amazonaws.com/sim/Mortalidade_Geral_2020.csv",  sep=";")
#    ORIGEM  TIPOBITO   DTOBITO  HORAOBITO  NATURAL  CODMUNNATU      DTNASC  \
# 0       1         2  18052020     1452.0    812.0    120010.0   7061932.0
# 1       1         2  20052020     2115.0    812.0    120010.0  16031952.0
# 2       1         2  21052020     1200.0    812.0    120010.0  17021961.0
# 3       1         2  21052020     1233.0    812.0    120010.0  10081942.0
# 4       1         2  22052020      730.0    812.0    120030.0  13041936.0
#
#    IDADE  SEXO  RACACOR  ...  FONTES  TPRESGINFO  TPNIVELINV  NUDIASINF  \
# 0    487     1      4.0  ...     NaN         NaN         NaN        NaN
# 1    468     2      4.0  ...     NaN         NaN         NaN        NaN
# ...

# %%
#retorna uma tupla que representa linhas e colunas como o valor das dimensões
dados2020.shape
# Out:
# (1556824, 87)

# %%
#Importar arquivo csv SIM 2021
#head() irá mostrar por padrão as 5 primeiras linhas do que existe dentro de um conjunto de dados dentro de um objeto do pandas
import pandas as pd
#(importando arquivo csv completo)
dados2021 = pd.read_csv("https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIM/Mortalidade_Geral_2021.csv",  sep=";")
dados2021.head()
# Out:
# <ipython-input-4-e5ecfd33e855>:5: DtypeWarning: Columns (66) have mixed types. Specify dtype option on import or set low_memory=False.
#   dados2021 = pd.read_csv("https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIM/Mortalidade_Geral_2021.csv",  sep=";")
#    ORIGEM  TIPOBITO   DTOBITO  HORAOBITO  NATURAL  CODMUNNATU      DTNASC  \
# 0       1         2  23032021     1500.0    811.0    110020.0  18061962.0
# 1       1         2  23032021      243.0    812.0    120050.0  19021971.0
# 2       1         2  23032021     1310.0    812.0    120040.0   1101956.0
# 3       1         2  17042021     2149.0    812.0    120050.0   6011999.0
# 4       1         2   6012021      420.0    812.0    120020.0  20082020.0
#
#    IDADE  SEXO  RACACOR  ...  FONTES  TPRESGINFO  TPNIVELINV  NUDIASINF  \
# 0    458     1      4.0  ...     NaN         NaN         NaN        NaN
# 1    450     1      4.0  ...     NaN         NaN         NaN        NaN
# ...

# %%
#dataframe escolhido
dados2021.shape
# Out:
# (1832649, 87)

# %%
#Importar arquivo csv SIM 2022
#head() irá mostrar por padrão as 5 primeiras linhas do que existe dentro de um conjunto de dados dentro de um objeto do pandas
dados2022 = pd.read_csv("https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIM/DO22OPEN.csv",  sep=";")
dados2022.head()
# Out:
# <ipython-input-6-3ea95d66e0e6>:3: DtypeWarning: Columns (66) have mixed types. Specify dtype option on import or set low_memory=False.
#   dados2022 = pd.read_csv("https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIM/DO22OPEN.csv",  sep=";")
#    ORIGEM  TIPOBITO   DTOBITO  HORAOBITO  NATURAL  CODMUNNATU      DTNASC  \
# 0       1         2  21042022     1230.0    835.0    355030.0  29041922.0
# 1       1         2  22042022     1203.0    827.0    270770.0   5071948.0
# 2       1         2  22042022     1525.0    835.0    354850.0  10101952.0
# 3       1         2  23042022      937.0    835.0    350750.0  25061938.0
# 4       1         2  20042022     1351.0    829.0    291400.0  18101956.0
#
#    IDADE  SEXO  RACACOR  ...  FONTES  TPRESGINFO  TPNIVELINV  NUDIASINF  \
# 0    499     2      1.0  ...     NaN         NaN         NaN        NaN
# 1    473     2      1.0  ...     NaN         NaN         NaN        NaN
# ...

# %%
dados2022.shape

# %% [markdown]
# Importandos os atributos relevantes após análise e escolha dos atributos relavantes
#
# ---

# %%
import pandas as pd
#(importando arquivo csv completo)
#dados2021 =pd.read_csv("https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIM/Mortalidade_Geral_2021.csv", usecols =['CODMUNRES','CAUSABAS','CODMUNNATU','IDADE','SEXO','RACACOR','ESTCIV', 'ESC','ESC2010','OCUP','CODMUNRES','CODMUNOCOR','LOCOCOR','LINHAA','ATESTADO','DTOBITO'],sep=';' )
#dados2021 = pd.read_csv("https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIM/Mortalidade_Geral_2021.csv",  sep=";")
dados2021.head()

# %% [markdown]
# # 2) Limpeza e tratamento de dados

# %%
dados2021.columns
# Out:
# Index(['ORIGEM', 'TIPOBITO', 'DTOBITO', 'HORAOBITO', 'NATURAL', 'CODMUNNATU',
#        'DTNASC', 'IDADE', 'SEXO', 'RACACOR', 'ESTCIV', 'ESC', 'ESC2010',
#        'SERIESCFAL', 'OCUP', 'CODMUNRES', 'LOCOCOR', 'CODESTAB', 'ESTABDESCR',
#        'CODMUNOCOR', 'IDADEMAE', 'ESCMAE', 'ESCMAE2010', 'SERIESCMAE',
#        'OCUPMAE', 'QTDFILVIVO', 'QTDFILMORT', 'GRAVIDEZ', 'SEMAGESTAC',
#        'GESTACAO', 'PARTO', 'OBITOPARTO', 'PESO', 'TPMORTEOCO', 'OBITOGRAV',
#        'OBITOPUERP', 'ASSISTMED', 'EXAME', 'CIRURGIA', 'NECROPSIA', 'LINHAA',
#        'LINHAB', 'LINHAC', 'LINHAD', 'LINHAII', 'CAUSABAS', 'CB_PRE',
#        'COMUNSVOIM', 'DTATESTADO', 'CIRCOBITO', 'ACIDTRAB', 'FONTE',
#        'NUMEROLOTE', 'TPPOS', 'DTINVESTIG', 'CAUSABAS_O', 'DTCADASTRO',
#        'ATESTANTE', 'STCODIFICA', 'CODIFICADO', 'VERSAOSIST', 'VERSAOSCB',
#        'FONTEINV', 'DTRECEBIM', 'ATESTADO', 'DTRECORIGA', 'CAUSAMAT',
#        'ESCMAEAGR1', 'ESCFALAGR1', 'STDOEPIDEM', 'STDONOVA', 'DIFDATA',
# ...

# %%
dados2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1832649 entries, 0 to 1832648
# Data columns (total 87 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   ORIGEM      int64
#  1   TIPOBITO    int64
#  2   DTOBITO     int64
#  3   HORAOBITO   float64
#  4   NATURAL     float64
#  5   CODMUNNATU  float64
#  6   DTNASC      float64
#  7   IDADE       int64
#  8   SEXO        int64
#  9   RACACOR     float64
#  10  ESTCIV      float64
#  11  ESC         float64
#  12  ESC2010     float64
#  13  SERIESCFAL  float64
#  14  OCUP        float64
#  15  CODMUNRES   int64
#  16  LOCOCOR     int64
#  17  CODESTAB    float64
#  18  ESTABDESCR  float64
#  19  CODMUNOCOR  int64
#  20  IDADEMAE    float64
#  21  ESCMAE      float64
#  22  ESCMAE2010  float64
#  23  SERIESCMAE  float64
#  24  OCUPMAE     float64
#  25  QTDFILVIVO  float64
#  26  QTDFILMORT  float64
#  27  GRAVIDEZ    float64
#  28  SEMAGESTAC  float64
#  29  GESTACAO    float64
#  30  PARTO       float64
# ...

# %%
dados2021.dtypes
# Out:
# ORIGEM          int64
# TIPOBITO        int64
# DTOBITO         int64
# HORAOBITO     float64
# NATURAL       float64
#                ...
# MORTEPARTO    float64
# DTCONCASO     float64
# FONTESINF     float64
# ALTCAUSA      float64
# CONTADOR        int64
# Length: 87, dtype: object

# %% [markdown]
# Um comando muito útil para avaliar uma Series é o .describe(), que irá calcular os quartis, valores máximo, mínimo, a média e o desvio padrão.

# %%
dados2021.describe()
# Out:
#              ORIGEM   TIPOBITO       DTOBITO     HORAOBITO       NATURAL  \
# count  1.832649e+06  1832649.0  1.832649e+06  1.777351e+06  1.743612e+06
# mean   1.000122e+00        2.0  1.577706e+07  1.204732e+03  8.248955e+02
# std    1.103028e-02        0.0  8.807187e+06  6.724415e+02  7.062751e+01
# min    1.000000e+00        2.0  1.012021e+06  0.000000e+00  4.000000e+00
# 25%    1.000000e+00        2.0  8.072021e+06  6.350000e+02  8.260000e+02
# 50%    1.000000e+00        2.0  1.603202e+07  1.210000e+03  8.310000e+02
# 75%    1.000000e+00        2.0  2.310202e+07  1.800000e+03  8.350000e+02
# max    2.000000e+00        2.0  3.112202e+07  2.200000e+04  9.990000e+02
#
#          CODMUNNATU        DTNASC         IDADE          SEXO       RACACOR  \
# count  1.718823e+06  1.829101e+06  1.832649e+06  1.832649e+06  1.790300e+06
# mean   3.210545e+05  1.544155e+07  4.629137e+02  1.445221e+00  2.243315e+00
# std    8.373553e+04  8.721011e+06  4.501474e+01  4.977396e-01  1.418723e+00
# ...

# %% [markdown]
# O método pandas.DataFrame.duplicated() é usado para localizar linhas duplicadas em um DataFrame. Ele retorna uma série booleana que identifica se uma linha é duplicada ou única.

# %%
dados2021.drop_duplicates()
# Out:
#          ORIGEM  TIPOBITO   DTOBITO  HORAOBITO  NATURAL  CODMUNNATU  \
# 0             1         2  23032021     1500.0    811.0    110020.0
# 1             1         2  23032021      243.0    812.0    120050.0
# 2             1         2  23032021     1310.0    812.0    120040.0
# 3             1         2  17042021     2149.0    812.0    120050.0
# 4             1         2   6012021      420.0    812.0    120020.0
# ...         ...       ...       ...        ...      ...         ...
# 1832644       1         2  24122021     1500.0    852.0    171240.0
# 1832645       1         2  18122021      130.0    852.0    521380.0
# 1832646       1         2  11102021     1600.0    821.0    210530.0
# 1832647       1         2   9072021     1420.0    823.0    231140.0
# 1832648       1         2  11072021      249.0    821.0    210160.0
#
#              DTNASC  IDADE  SEXO  RACACOR  ...  FONTES  TPRESGINFO  \
# 0        18061962.0    458     1      4.0  ...     NaN         NaN
# ...

# %%
# Apagar as linhas com qualquer valor nulo em qualquer variável
dados_sem_nulos = dados2021.dropna(how = 'any')

# %%
maxIdade = dados2021['IDADE'].max()
maxIdade
# Out:
# 999

# %% [markdown]
# OBS: # Idade do falecido em minutos, horas, dias, meses ou anos. (Idade: composto de dois subcampos. - O primeiro, de 1 dígito, indica a unidade da idade (se 1 = minuto, se 2 = hora, se 3 = mês, se 4 = ano, se = 5 idade maior que 100 anos). - O segundo, de dois dígitos, indica a quantidade de unidades: Idade menor de 1 hora: subcampo varia de 01 e 59 (minutos); De 1 a 23 Horas: subcampo varia de 01 a 23 (horas); De 24 horas e 29 dias: subcampo varia de 01 a 29 (dias); De 1 a menos de 12 meses completos: subcampo varia de 01 a 11 (meses); Anos - subcampo varia de 00 a 99; - 9 - ignorado)

# %%
# tratamento para campo idade
dados2021.query('IDADE<=600' ,inplace=True)

# %%
minIdade = dados2021['IDADE'].min()
minIdade
# Out:
# 1

# %%
maxIdade = dados2021['IDADE'].max()
maxIdade
# Out:
# 524

# %%
dados2021['IDADE2']=dados2021['IDADE'].apply(lambda x: 0 if x <400 else x)

# %%
minIdade = dados2021['IDADE2'].min()
minIdade
# Out:
# 0

# %%
maxIdade = dados2021['IDADE2'].max()
maxIdade
# Out:
# 524

# %%
#**SUBTRAIR** 400 IDADE
dados2021['IDADE2']=dados2021['IDADE2'].apply(lambda x: x-400 if x >=400 else x)

# %%
maxIdade2 = dados2021['IDADE2'].max()
maxIdade2
# Out:
# 124

# %% [markdown]
# # 3) Análise dos dados

# %%
## Ordenando os dados após o groupby

contagem_idade = dados2021['IDADE2'].value_counts().reset_index()
contagem_idade = contagem_idade.rename(columns={'index': 'IDADE2', 'IDADE2': 'quantidade'})
contagem_idade = contagem_idade.sort_values(by='quantidade', ascending=False)
print(contagem_idade)
# Out:
#      IDADE2  quantidade
# 0        73       40136
# 1        74       39820
# 2        71       39807
# 3        81       39607
# 4        78       39370
# ..      ...         ...
# 119     119           3
# 120     118           2
# 121     120           2
# 122     124           1
# 123     122           1
#
# [124 rows x 2 columns]

# %%
# Realizar describe()  para o campo 'Idade2'
descricao_idade = dados2021['IDADE2'].describe()

# %%
# Exibir a descrição
print(descricao_idade)
# Out:
# count    1.830272e+06
# mean     6.563752e+01
# std      2.051598e+01
# min      0.000000e+00
# 25%      5.500000e+01
# 50%      6.900000e+01
# 75%      8.100000e+01
# max      1.240000e+02
# Name: IDADE2, dtype: float64

# %%
dados2021.IDADE2.plot.hist();

# %%
#criar coluna covid true ou false
dados2021['COVID']= dados2021.CAUSABAS.apply(lambda x: True if x=='B342' else False )

# %%
dados2021.duplicated()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1832644    False
# 1832645    False
# 1832646    False
# 1832647    False
# 1832648    False
# Length: 1830272, dtype: bool

# %%
dados2021.SEXO.value_counts(normalize=True)
# Out:
# 1    0.553747
# 2    0.446059
# 0    0.000194
# Name: SEXO, dtype: float64

# %%
dados2021['SEXO']=dados2021['SEXO'].replace([0,1, 2] ,['Indefinido','Masculino' , 'Feminino' ])
dados2021
# Out:
#          ORIGEM  TIPOBITO   DTOBITO  HORAOBITO  NATURAL  CODMUNNATU  \
# 0             1         2  23032021     1500.0    811.0    110020.0
# 1             1         2  23032021      243.0    812.0    120050.0
# 2             1         2  23032021     1310.0    812.0    120040.0
# 3             1         2  17042021     2149.0    812.0    120050.0
# 4             1         2   6012021      420.0    812.0    120020.0
# ...         ...       ...       ...        ...      ...         ...
# 1832644       1         2  24122021     1500.0    852.0    171240.0
# 1832645       1         2  18122021      130.0    852.0    521380.0
# 1832646       1         2  11102021     1600.0    821.0    210530.0
# 1832647       1         2   9072021     1420.0    823.0    231140.0
# 1832648       1         2  11072021      249.0    821.0    210160.0
#
#              DTNASC  IDADE       SEXO  RACACOR  ...  TPNIVELINV  NUDIASINF  \
# ...

# %%
dados2020['SEXO']=dados2021['SEXO'].replace([0,1, 2] ,['Indefinido','Masculino' , 'Feminino' ])
dados2020
# Out:
#          ORIGEM  TIPOBITO   DTOBITO  HORAOBITO  NATURAL  CODMUNNATU  \
# 0             1         2  18052020     1452.0    812.0    120010.0
# 1             1         2  20052020     2115.0    812.0    120010.0
# 2             1         2  21052020     1200.0    812.0    120010.0
# 3             1         2  21052020     1233.0    812.0    120010.0
# 4             1         2  22052020      730.0    812.0    120030.0
# ...         ...       ...       ...        ...      ...         ...
# 1556819       1         2  31122020     2020.0    831.0    316960.0
# 1556820       1         2  31122020     1220.0    817.0    172100.0
# 1556821       1         2  31122020        NaN    826.0    261580.0
# 1556822       1         2  31122020     2100.0    841.0    410830.0
# 1556823       1         2  31122020     1632.0    817.0    170300.0
#
#              DTNASC  IDADE       SEXO  RACACOR  ...  FONTES  TPRESGINFO  \
# 0         7061932.0    487  Masculino      4.0  ...     NaN         NaN
# ...

# %%
contagem_causa2021 = dados2021['CAUSABAS'].value_counts().reset_index()
contagem_causa2021 = contagem_causa2021.rename(columns={'index': 'CAUSABAS', 'CAUSABAS': 'quantidade'})
contagem_causa2021 = contagem_causa2021.sort_values(by='quantidade', ascending=False)
print(contagem_causa2021)
# Out:
#      CAUSABAS  quantidade
# 0        B342      424430
# 1        I219       93297
# 2         R99       60502
# 3         I10       39963
# 4         I64       35798
# ...       ...         ...
# 4869     Q821           1
# 4870     G622           1
# 4871     Y352           1
# 4872     E728           1
# 5568     E012           1
#
# [5569 rows x 2 columns]

# %%
contagem_causa2020 = dados2020['CAUSABAS'].value_counts().reset_index()
contagem_causa2020 = contagem_causa2020.rename(columns={'index': 'CAUSABAS', 'CAUSABAS': 'quantidade'})
contagem_causa2020 = contagem_causa2020.sort_values(by='quantidade', ascending=False)
print(contagem_causa2020)
# Out:
#      CAUSABAS  quantidade
# 0        B342      212706
# 1        I219       87961
# 2         R99       58899
# 3         I10       37600
# 4        J189       36907
# ...       ...         ...
# 4842     R908           1
# 4843     Y443           1
# 4844     P743           1
# 4845     H652           1
# 5497     X792           1
#
# [5498 rows x 2 columns]

# %%
contagem_causa2022 = dados2022['CAUSABAS'].value_counts().reset_index()
contagem_causa2022 = contagem_causa2022.rename(columns={'index': 'CAUSABAS', 'CAUSABAS': 'quantidade'})
contagem_causa2022 = contagem_causa2022.sort_values(by='quantidade', ascending=False)
print(contagem_causa2022)
# Out:
#      CAUSABAS  quantidade
# 0        I219       95072
# 1        B342       65764
# 2         R99       51261
# 3        J189       48072
# 4         I10       39220
# ...       ...         ...
# 4884     K092           1
# 4885     O689           1
# 4886     M620           1
# 4887      R69           1
# 5538     P119           1
#
# [5539 rows x 2 columns]

# %% [markdown]
# *I219 Infarto agudo do miocárdio não especificado
#
# *B342 INFECÇÃO POR CORONAVÍRUS DE LOCALIZAÇÃO NÃO ESPECIFICADA
#
# *R99 Outras causas mal definidas e as não especificadas de mortalidade
#
# *J189 Pneumonia não especificada
#
# *I10 Hipertensão essencial (primária)

# %%
#Comparando casudas de óbtitos 2022
contagem_causa2022 = dados2022['CAUSABAS'].value_counts().reset_index()
contagem_causa2022 = contagem_causa2022.rename(columns={'index': 'CAUSABAS', 'CAUSABAS': 'quantidade'})
contagem_causa2022 = contagem_causa2022.sort_values(by='quantidade', ascending=False)
print(contagem_causa2022)
# Out:
#      CAUSABAS  quantidade
# 0        I219       95072
# 1        B342       65764
# 2         R99       51261
# 3        J189       48072
# 4         I10       39220
# ...       ...         ...
# 4884     K092           1
# 4885     O689           1
# 4886     M620           1
# 4887      R69           1
# 5538     P119           1
#
# [5539 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
dados2021.SEXO.value_counts(normalize=True).plot(kind='pie',autopct='%1.1f%%')
plt.axis('equal')  # Para garantir que o gráfico seja exibido como um círculo
plt.title('Quantidade Óbitos no Brasil em 2021 por Sexo')  # Adicionando o título do gráfico
plt.show()

# %%
#criar coluna covid true ou false
dados2021['COVID']= dados2021.CAUSABAS.apply(lambda x: True if x=='B342' else False )

# %%
dados2021.query('COVID==True' ,inplace=True)

# %%
dados2021
# Out:
#          ORIGEM  TIPOBITO   DTOBITO  HORAOBITO  NATURAL  CODMUNNATU  \
# 0             1         2  23032021     1500.0    811.0    110020.0
# 1             1         2  23032021      243.0    812.0    120050.0
# 2             1         2  23032021     1310.0    812.0    120040.0
# 6             1         2  15022021        NaN    812.0    120050.0
# 10            1         2  13022021      503.0    812.0    120050.0
# ...         ...       ...       ...        ...      ...         ...
# 1832565       1         2  26122021     2122.0    852.0    520870.0
# 1832605       1         2   5072021     2058.0    815.0    150220.0
# 1832606       1         2   8072021     1355.0    821.0    210950.0
# 1832617       1         2  15122021     1456.0    852.0    170190.0
# 1832628       1         2  29122021     1637.0    817.0    171820.0
#
#              DTNASC  IDADE       SEXO  RACACOR  ...  TPNIVELINV  NUDIASINF  \
# ...

# %% [markdown]
# # 3.1) Estatística Descritiva

# %%
# Medidas de tendência
# Calcular as medidas de tendência central para idade  após filtro covid
# Média
x = dados2021.IDADE2.mean()
print('Média:', round(x, 2))
# Mediana
y = dados2021.IDADE2.median()
print('Mediana:', y)
# Moda
z = dados2021.IDADE2.mode()
print('Moda:', z)
# Out:
# Média: 64.83
# Mediana: 66.0
# Moda: 0    66
# Name: IDADE2, dtype: int64

# %%
#Medidas de dispersão
# Calcular as medidas de dispersão da idade
# Mínimo
min = dados2021.IDADE2.min()
# Máximo
max = dados2021.IDADE2.max()
# Intervalo
print('Intervalo:', min, ' - ', max)
# Variância
var = dados2021.IDADE2.var()
print('Variância:', round(var, 2))
# Desvio padrão
std = dados2021.IDADE2.std()
print('Desvio Padrão:', round(std, 2))
# Out:
# Intervalo: 0  -  120
# Variância: 250.62
# Desvio Padrão: 15.83

# %%
dados2021['Contador_COVID'] = [i for i, _ in enumerate(dados2021['COVID'], 1)]

# %%
dados2021.shape
# Out:
# (424430, 90)

# %%
# Distribuição de frequência
# Frequência absoluta
fa = dados2021.SEXO.value_counts()
print('Frequência absoluta')
print(fa)
# Frequência relativa
fr = dados2021.SEXO.value_counts(normalize = True)
print('Frequência relativa')
print(fr)
# Tabela de frequência (incluindo os valores nulos)
fan = dados2021.SEXO.value_counts(dropna=False)
print('Frequência absoluta considerando os nulos')
print(fan)
# Tabela de frequência relativa (incluindo os valores nulos)
frn = dados2021.SEXO.value_counts(normalize = True, dropna=False)
print('Frequência relativa considerando os nulos')
# Out:
# Frequência absoluta
# Masculino     235779
# Feminino      188606
# Indefinido        45
# Name: SEXO, dtype: int64
# Frequência relativa
# Masculino     0.555519
# Feminino      0.444375
# Indefinido    0.000106
# Name: SEXO, dtype: float64
# Frequência absoluta considerando os nulos
# Masculino     235779
# Feminino      188606
# Indefinido        45
# Name: SEXO, dtype: int64
# Frequência relativa considerando os nulos

# %%
import matplotlib.pyplot as plt
dados2021.SEXO.value_counts(normalize=True).plot(kind='pie',autopct='%1.1f%%')
plt.axis('equal')  # Para garantir que o gráfico seja exibido como um círculo
plt.title('Quantidade de Óbitos por COVID19 no Brasil em 2021 por Sexo')  # Adicionando o título do gráfico
plt.show()

# %%
dados2021.SEXO.value_counts(normalize=True).plot(kind='bar')
# Out:
# <Axes: >

# %%
dados2021.RACACOR.value_counts(normalize=True)
# Out:
# 1.0    0.575013
# 4.0    0.338561
# 2.0    0.078069
# 3.0    0.006261
# 5.0    0.002095
# Name: RACACOR, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Criar um gráfico de boxplot agrupado
sns.boxplot(x='SEXO', y='IDADE2', data=dados2021)

# Personalizar o gráfico
plt.title('Gráfico Óbitos por COVID-19 2021 Sexo x Idade')
plt.xlabel('Sexo')
plt.ylabel('Idade')

# Exibir o gráfico
plt.show()

# %%
dados2021['RACACOR']=dados2021['RACACOR'].replace([1,2,3,4,5], ['Branca','Preta' , 'Amarela', 'Parda', 'Indígena'])

dados2021
# Out:
#          ORIGEM  TIPOBITO   DTOBITO  HORAOBITO  NATURAL  CODMUNNATU  \
# 0             1         2  23032021     1500.0    811.0    110020.0
# 1             1         2  23032021      243.0    812.0    120050.0
# 2             1         2  23032021     1310.0    812.0    120040.0
# 6             1         2  15022021        NaN    812.0    120050.0
# 10            1         2  13022021      503.0    812.0    120050.0
# ...         ...       ...       ...        ...      ...         ...
# 1832565       1         2  26122021     2122.0    852.0    520870.0
# 1832605       1         2   5072021     2058.0    815.0    150220.0
# 1832606       1         2   8072021     1355.0    821.0    210950.0
# 1832617       1         2  15122021     1456.0    852.0    170190.0
# 1832628       1         2  29122021     1637.0    817.0    171820.0
#
#              DTNASC  IDADE       SEXO RACACOR  ...  NUDIASINF DTCADINF  \
# 0        18061962.0    458  Masculino   Parda  ...        NaN      NaN
# ...

# %%
dados2021.RACACOR.value_counts(normalize=True).plot(kind='bar', color='green')
# Out:
# <Axes: >

# %% [markdown]
# RACACOR =Cor informada pelo responsável pelas informações do falecido. (1 – Branca; 2 – Preta; 3 – Amarela; 4 – Parda; 5 – Indígena)

# %%
import matplotlib.ticker as mtick
cores = ['red', 'green', 'blue', 'yellow', 'orange']  # Lista de cores para cada categoria
dados2021.RACACOR.value_counts(normalize=True).plot(kind='bar', color=cores)
plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter(decimals=1))
plt.title('Quantidade de Óbitos por COVID19 no Brasil em 2021 por Raça/Cor')  # Adicionando o título do gráfico
plt.xlabel('Raça/Cor')
plt.ylabel('Percentual')
# Out:
# Text(0, 0.5, 'Percentual')

# %%
dados2021.LOCOCOR.value_counts(normalize=True)
# Out:
# 1    0.915534
# 2    0.055804
# 3    0.022034
# 5    0.005608
# 4    0.000879
# 9    0.000130
# 6    0.000012
# Name: LOCOCOR, dtype: float64

# %% [markdown]
# Local
# de ocorrência do óbito. (1 – hospital; 2 – outros
# estabelecimentos de
# saúde; 3 – domicílio; 4 – via pública; 5 – outros; 6 - aldeia indígena; 9
# –
# ignorado).

# %%
dados2021['LOCOCOR']=dados2021['LOCOCOR'].replace([1,2,3,4,5,6,9], ['Hospital','Outros estabelecimentos de saúde' , 'Domicílio', 'Via Pública', 'Outros','Aldeia indígena','Ignorado'])

# %%
import matplotlib.ticker as mtick
cores = ['red', 'green', 'blue', 'yellow', 'orange']  # Lista de cores para cada categoria
dados2021.LOCOCOR.value_counts(normalize=True).plot(kind='bar', color=cores)
plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter(decimals=1))
plt.title('Quantidade de Óbitos por COVID19 no Brasil em 2021 por Local de Ocorrência do Óbito')  # Adicionando o título do gráfico
plt.xlabel('Local de Ocorrência')
plt.ylabel('Percentual')
# Out:
# Text(0, 0.5, 'Percentual')

# %%
dados2021.ESC2010.value_counts(normalize=True)
# Out:
# 1.0    0.287566
# 3.0    0.220230
# 2.0    0.162569
# 9.0    0.114814
# 5.0    0.098497
# 0.0    0.097981
# 4.0    0.018342
# Name: ESC2010, dtype: float64

# %%
dados2021['ESC2010']=dados2021['ESC2010'].replace([0,1,2,3,4,5,9], ['Sem escolaridade','Fundamental I' , 'Fundamental II', 'de 8 a 11 anosMédio (antigo 2° grau)', 'Superiorincompleto','Superior completo','Ignorado'])

# %%
dados2021.ESC2010.value_counts(normalize=True).plot(kind='bar')
plt.title('Quantidade de Óbitos por COVID19 no Brasil em 2021 por Escolaridade')
# Out:
# Text(0.5, 1.0, 'Quantidade de Óbitos por COVID19 no Brasil em 2021 por Escolaridade')

# %% [markdown]
# ESC
# 3 Escolaridade em anos. (1 – Nenhuma; 2 – de 1 a 3 anos; 3 – de 4 a 7 anos; 4 – de 8 a 11 anos; 5 – 12 anos e mais; 9 – Ignorado)

# %%
dados2021.ESC
# Out:
# 0          3.0
# 1          3.0
# 2          3.0
# 6          9.0
# 10         9.0
#           ...
# 1832565    9.0
# 1832605    5.0
# 1832606    2.0
# 1832617    3.0
# 1832628    2.0
# Name: ESC, Length: 424430, dtype: float64

# %%
dados2021['ESC']=dados2021['ESC'].replace([1,2,3,4,5,9], ['Nenhuma','de 1 a 3 anos' , 'de 4 a 7 anos', 'de 8 a 11 anos', '12 anos e mais','Ignorado'])

# %%
dados2021.ESC.value_counts(normalize=True).plot(kind='bar')
plt.title('Quantidade de Óbitos por COVID19 no Brasil em 2021 por Escolaridade em Anos')
# Out:
# Text(0.5, 1.0, 'Quantidade de Óbitos por COVID19 no Brasil em 2021 por Escolaridade em Anos')

# %%
# Agrupando por 'CODMUNOCOR', 'RACACOR' e 'SEXO', e contando as ocorrências de 'CAUSABAS'
grouped_data = dados2021.groupby(['CODMUNOCOR', 'RACACOR', 'SEXO', 'CAUSABAS']).size().reset_index(name='quantidade')
grouped_data = grouped_data.sort_values(by='quantidade', ascending=False)
print(grouped_data)
# Out:
#        CODMUNOCOR  RACACOR       SEXO CAUSABAS  quantidade
# 9540       355030   Branca  Masculino     B342       10395
# 9538       355030   Branca   Feminino     B342        7922
# 7440       330455   Branca  Masculino     B342        5657
# 7439       330455   Branca   Feminino     B342        5069
# 10133      410690   Branca  Masculino     B342        3716
# ...           ...      ...        ...      ...         ...
# 4644       292150  Amarela   Feminino     B342           1
# 2307       230810   Branca  Masculino     B342           1
# 4643       292145   Branca  Masculino     B342           1
# 4642       292130    Preta  Masculino     B342           1
# 5191       310350  Amarela   Feminino     B342           1
#
# [13730 rows x 5 columns]

# %% [markdown]
# * ATESTADO = CIDs informados no atestado. (Códigos CID 10)
# * CID B34.2 – INFECÇÃO POR CORONAVÍRUS DE LOCALIZAÇÃO NÃO ESPECIFICADA
# * IDADE
# * INSTRUCAO = Instrução, conforme a tabela: 1979 (C 9)
#  * 0: Ignorado
#  *1: Nenhuma
#  *2: Primeiro grau
#  *3: Segundo grau
#  *4: Superior
# * OCUPACAO =Ocupação, conforme a Classificação Brasileira de Ocupações (CBO)
# * RACACOR =Cor informada pelo responsável pelas informações do falecido. (1 – Branca; 2
# – Preta; 3 – Amarela; 4 – Parda; 5 – Indígena)
# * SEXO =Sexo do falecido. “Ignorado” selecionada em casos especiais como cadáveres mutilados, em estado avançado de decomposição, genitália indefinida ou hermafroditismo. (M – masculino; F – feminino; I - ignorado)

# %% [markdown]
# Tentar entender quais variavéis desse conjunto de dados são mais relevantes ao óbito por cid/doença.

# %% [markdown]
# C34 - Neoplasia Maligna dos Brônquios e dos Pulmões
# C18 Neoplasia maligna do cólon
# C22 - Neoplasia maligna do fígado e das vias biliares intra-hepáticas
# C16 - Neoplasia maligna do estômago
# C50 – Neoplasia Maligna da Mama

# %% [markdown]
# LINHAAA = CIDs informados na Linha
# A da DO referente ao diagnóstico na Linha A da
# DO (causa terminal - doença ou estado mórbido que causou diretamente
# a
# morte). (Códigos CID 10

# %%
dados2021.to_csv("obitos2021_2.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')
